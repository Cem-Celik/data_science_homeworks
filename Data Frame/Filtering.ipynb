# %% [markdown]
# For Pandas assignments, you are going to use Titanic (train.csv) dataset. Download the dataset and load to a DataFrame.

# %%
import pandas as pd
import numpy as np

train_df = pd.read_csv("data/train.csv", index_col = 0)
train_df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# 1- By using conditional selection methods, calculate the survival rate for all passengers under 30 years old.

# %%
survived_under_30 = train_df[(train_df['Age']<30) & (train_df['Survived'] == 1)]

survival_rate = survived_under_30.shape[0]*100/train_df.shape[0]

print("Survival rate for all passengers under 30 years old is {:.2f}%".format(survival_rate))
# Out:
# Survival rate for all passengers under 30 years old is 17.51%

# %% [markdown]
# 2- Calculate the survival rate by gender.

# %%
train_males = train_df[train_df['Sex'] == "male"]
survived_tm = train_males[train_males['Survived'] == 1]

train_females = train_df[train_df['Sex'] == "female"]
survived_tf = train_females[train_females['Survived'] == 1]

survival_rate_m = survived_tm.shape[0]/train_males.shape[0]*100
survival_rate_f = survived_tf.shape[0]/train_females.shape[0]*100

print("Surviving rate by gender:\nMales have {:.2f}% survival rate\nFemales have {:.2f}% survival rate".format(survival_rate_m,survival_rate_f))
# Out:
# Surviving rate by gender:
# Males have 18.89% survival rate
# Females have 74.20% survival rate
